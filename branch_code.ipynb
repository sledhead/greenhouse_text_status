# %%
#playing around with git branching for code...

# %%
#adding some basic code for the new branch
for i in range(1,15,1):
  print(f'Here is the number: {i}')
# Out:
# Here is the number: 1
# Here is the number: 2
# Here is the number: 3
# Here is the number: 4
# Here is the number: 5
# Here is the number: 6
# Here is the number: 7
# Here is the number: 8
# Here is the number: 9
# Here is the number: 10
# Here is the number: 11
# Here is the number: 12
# Here is the number: 13
# Here is the number: 14

# %%
test_dic = { 'one': 'cars', 'two':'foods','three':'islands'}

for key,val in test_dic.items():
  print(f'Key value is: {key}.  Vaule is: {val}')
# Out:
# Key value is: one.  Vaule is: cars
# Key value is: two.  Vaule is: foods
# Key value is: three.  Vaule is: islands

# %%
sort_test = {1:'martin', 5:'bill', 3:'mark', 9:'seth', 6:'cathy',8:'jim'}

for key_num in sorted(sort_test.keys()):
  print(key_num)
# Out:
# 1
# 3
# 5
# 6
# 8
# 9

# %%
def look_for_Key(dic,key):
  if key in dic.keys():
    print("Present, value =", dic[key])
  else:
    print("Not present")


test_dict = {'J-13':'snow', 'J-23':'light', 'J-2':'mikl', 'J-55':'sea', 'J-7':'japan'}

look_for_Key(test_dict,'J-23')
# Out:
# Present, value = light

# %%
look_for_Key(test_dict,'J-5')
# Out:
# Not present

# %%
for i_num in range(1,60,1):

  #build possible key string
  find_key_str = f'J-{i_num}'

  #call function to determine if requested key str exists.
  look_for_Key(test_dict,find_key_str)
# Out:
# Not present
# Present, value = mikl
# Not present
# Not present
# Not present
# Not present
# Present, value = japan
# Not present
# Not present
# Not present
# Not present
# Not present
# Present, value = snow
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Present, value = light
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Not present
# Present, value = sea
# Not present
# Not present
# Not present
# Not present

# %%
key_list = test_dict.keys()
print(key_list)
print(type(key_list))
# Out:
# dict_keys(['J-13', 'J-23', 'J-2', 'J-55', 'J-7'])
# <class 'dict_keys'>

# %%
simple_list = list(key_list)
print(type(simple_list))
print(simple_list)
print(simple_list.sort())
# Out:
# <class 'list'>
# ['J-13', 'J-23', 'J-2', 'J-55', 'J-7']
# None

# %%
gg = 'J-45'
hh = gg.split('-')
print(type(gg))
print(hh)
# Out:
# <class 'str'>
# ['J', '45']

# %%
vv = ['J-13', 'J-23', 'J-2', 'J-55', 'J-7']
print(type(vv))
print(vv.sort())
print(vv)

def special_sort(ele):
  #take the string passed in and return the number.
  #split the letter from the number and return the num
  temp_lst = ele.split('-')
  temp_num = int(temp_lst[1])
  return temp_num
# Out:
# <class 'list'>
# None
# ['J-13', 'J-2', 'J-23', 'J-55', 'J-7']

# %%
vv.sort(key=special_sort)
print(vv)
# Out:
# ['J-2', 'J-7', 'J-13', 'J-23', 'J-55']

# %%
for job_num in vv:
  print("Before job")
  print(f'Working on this job: {job_num}')
  print(f'Here is the dict value: {test_dict[job_num]}')
  print("After job")
  print("******************************************")


print(f'Total number of items processed were: {len(vv)}')
# Out:
# Before job
# Working on this job: J-2
# Here is the dict value: mikl
# After job
# ******************************************
# Before job
# Working on this job: J-7
# Here is the dict value: japan
# After job
# ******************************************
# Before job
# Working on this job: J-13
# Here is the dict value: snow
# After job
# ******************************************
# Before job
# Working on this job: J-23
# Here is the dict value: light
# After job
# ******************************************
# Before job
# Working on this job: J-55
# Here is the dict value: sea
# After job
# ******************************************
# Total number of items processed were: 5

# %%
def myfunc(a, b):
  return a + b

x = map(myfunc, ('apple', 'banana', 'cherry'), ('orange', 'lemon', 'pineapple'))

# %%
def GetNum(j_num):
  temp_lst = j_num.split('-')
  temp_num = int(temp_lst[1])
  return temp_num

# %%
print(type(x))
print(tuple(x))

just_nums = map(GetNum, key_list)

print(list(just_nums))
# Out:
# <class 'map'>
# ()
# [13, 23, 2, 55, 7]

# %%
def fun(variable):
    letters = ['a', 'e', 'i', 'o', 'u']
    if (variable in letters):
        return True
    else:
        return False
  
  
# sequence
sequence = ['g', 'e', 'e', 'j', 'k', 's', 'p', 'r']
  
# using filter function
filtered = filter(fun, sequence)

print(list(filtered))
  
print('The filtered letters are:')
for s in filtered:
    print(s)
# Out:
# ['e', 'e']
# The filtered letters are:

# %%
print(list(filtered))
# Out:
# []
